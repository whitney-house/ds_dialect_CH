# %%
import pandas as pd

# %%
data_df = pd.read_csv('forms.csv')
data_df
# Out:
#                         ID  Local_ID Language_ID Parameter_ID  \
# 0       Beijing-91_vomit-1       NaN     Beijing     91_vomit
# 1       Haerbin-91_vomit-1       NaN     Haerbin     91_vomit
# 2         Jinan-91_vomit-1       NaN       Jinan     91_vomit
# 3     Rongcheng-91_vomit-1       NaN   Rongcheng     91_vomit
# 4       Taiyuan-91_vomit-1       NaN     Taiyuan     91_vomit
# ...                    ...       ...         ...          ...
# 4297  Guangzhou-90_woman-1       NaN   Guangzhou     90_woman
# 4298     Fuzhou-90_woman-1       NaN      Fuzhou     90_woman
# 4299     Fuzhou-90_woman-2       NaN      Fuzhou     90_woman
# 4300     Fuzhou-90_woman-3       NaN      Fuzhou     90_woman
# 4301     Xiamen-90_woman-1       NaN      Xiamen     90_woman
#
#                        Value                    Form  \
# 0                      tʰu⁵¹                   tʰu⁵¹
# 1                      tʰu⁵³                   tʰu⁵³
# 2                      tʰu³¹                   tʰu³¹
# 3            ou²¹³⁻³⁵ tʰu²¹⁴         ou²¹³⁻³⁵ tʰu²¹⁴
# 4                  tʰu⁵³ lə⁰               tʰu⁵³ lə⁰
# ...                      ...                     ...
# 4297          nøy²³ iɐn²¹⁻²³          nøy²³ iɐn²¹⁻²³
# 4298           i⁵⁵⁻⁵³ tsia³²           i⁵⁵⁻⁵³ tsia³²
# 4299            ny³²⁻⁵⁵ ɛ²¹²            ny³²⁻⁵⁵ ɛ²¹²
# 4300  tsy⁵⁵ nøyŋ⁵³⁻⁵⁵ nøyŋ⁵³  tsy⁵⁵ nøyŋ⁵³⁻⁵⁵ nøyŋ⁵³
# 4301  tsa⁵⁵⁻²² bɔ⁵³⁻⁵⁵ laŋ²⁴  tsa⁵⁵⁻²² bɔ⁵³⁻⁵⁵ laŋ²⁴
#
#                              Segments              Comment   Source  Cognacy  \
# 0                             tʰ u ⁵¹                  NaN  Liu2007      NaN
# 1                             tʰ u ⁵³                  NaN  Liu2007      NaN
# 2                             tʰ u ³¹                  NaN  Liu2007      NaN
# 3                   ou ²¹³ + tʰ u ²¹⁴  copulative synonyme  Liu2007      NaN
# 4                     tʰ u ⁵³ + l ə ⁰                  NaN  Liu2007      NaN
# ...                               ...                  ...      ...      ...
# 4297               n øy ²³ + j ɐ n ²¹                  NaN  Liu2007      NaN
# 4298                 i ⁵⁵ + ts j a ³²                  NaN  Liu2007      NaN
# 4299                   n y ³² + ɛ ²¹²                  NaN  Liu2007      NaN
# 4300  ts y ⁵⁵ + n øy ŋ ⁵³ + n øy ŋ ⁵³                  NaN  Liu2007      NaN
# 4301      ts a ⁵⁵ + b ɔ ⁵³ + l a ŋ ²⁴                  NaN  Liu2007      NaN
#
#       Loan  Graphemes  Profile                    Prosody  \
# 0      NaN        NaN      NaN                      i n t
# 1      NaN        NaN      NaN                      i n t
# 2      NaN        NaN      NaN                      i n t
# 3      NaN        NaN      NaN                n t + i n t
# 4      NaN        NaN      NaN              i n t + i n t
# ...    ...        ...      ...                        ...
# 4297   NaN        NaN      NaN            i n t + i n c t
# 4298   NaN        NaN      NaN              n t + i m n t
# 4299   NaN        NaN      NaN                i n t + n t
# 4300   NaN        NaN      NaN  i n t + i n c t + i n c t
# 4301   NaN        NaN      NaN    i n t + i n t + i n c t
#
#                 Morpheme_Glosses Partial_Cognacy Chinese_Characters
# 0                         spit/吐               1                  吐
# 1                         spit/吐               1                  吐
# 2                         spit/吐               1                  吐
# 3                nausea/嘔 spit/吐             2 1                嘔 吐
# 4        nausea/嘔 _:PERFECTIVE/了             2 5                嘔 嘞
# ...                          ...             ...                ...
# 4297          female/女 _person/人           39 38                女 人
# 4298            woman/伊 sister/姐         824 715                伊 姐
# 4299           female/女 _world/界          39 825                女 界
# 4300  woman/諸 female/娘 _person/人       749 31 38              諸 娘 儂
# 4301    woman/查 wife/某 _person/人       750 53 38              查 某 人
#
# [4302 rows x 17 columns]

# %% [markdown]
# step 1 extract all the parameter_ID/ Language_ID to decide how many words we are inverstigating

# %%
# 19 cities 
cities = data_df['Language_ID'].unique()
cities
# Out:
# array(['Beijing', 'Haerbin', 'Jinan', 'Rongcheng', 'Taiyuan', 'XiAn',
#        'Chengdu', 'Nanjing', 'Jixi', 'Suzhou', 'Wenzhou', 'Changsha',
#        'Loudi', 'Nanchang', 'Meixian', 'Guilin', 'Guangzhou', 'Fuzhou',
#        'Xiamen'], dtype=object)

# %%
# 203 words 
words = data_df['Parameter_ID'].unique()
words
# Out:
# array(['91_vomit', '92_fear', '93_skin', '94_float', '95_smooth',
#        '96_wife', '97_all', '98_hot', '99_person', '100_throw', '1_white',
#        '2_back', '3_nose', '4_ice', '5_neck', '6_thin', '7_not', '8_rub',
#        '9_grass', '10_long', '101_flesh', '102_if', '103_breasts',
#        '104_three', '105_woods', '106_kill', '107_sand', '108_mountain',
#        '109_burn', '110_few', '111_tongue', '112_snake', '113_rope',
#        '114_louse', '115_wet', '116_what', '117_stone', '118_hand',
#        '119_tree', '120_bark', '121a_countnoun', '121b_countverb',
#        '122_who', '123_water', '124_fruit', '125_sleep', '126_suck',
#        '127_say', '128_split', '129_die', '130_four', '131_he',
#        '132_they', '133_sun', '134_lie', '135_day', '136_sky', '137_hear',
#        '138_head', '139_hair', '140_earth', '141_spit', '142_push',
#        '143_leg', '144_dig', '145_play', '146_night', '147_tail',
#        '148_smell', '149_i', '150_we', '151_five', '152_fog', '153_knee',
#        '154_wash', '155_think', '156_small', '157_laugh', '158_heart',
#        '202_heartcompound', '159_new', '160_star', '161_snow',
#        '162_blood', '163_squeeze', '164_tooth', '165_smoke', '166_salt',
#        '167_eye', '168_bite', '169_leaf', '170_one', '171_because',
#        '172_swim', '173_rightside', '174_fish', '175_feather', '176_rain',
#        '177_round', '178_far', '179_moon', '180_cloud', '181_in',
#        '182_dirty', '183_how', '184_narrow', '185_stand', '186_husband',
#        '187_this', '188_here', '189_know', '190_grease', '191_straight',
#        '192_swell', '193_seed', '194_heavy', '195_scratch', '196_claw',
#        '197_turn', '198_walk', '199_mouth', '200_leftside', '201_sit',
#        '11_guts', '12_sing', '13_dust', '14_eat', '15_wing', '16_worm',
#        '17_blow', '18_stab', '19_hit', '20_fight', '21_hunt', '22_big',
#        '23_dull', '24_fall', '25_animal', '26_belly', '27_short',
#        '28_correct', '29_many', '30_ear', '31_two', '32_fly', '33_wind',
#        '34_sew', '35_rotten', '36_father', '37_dry', '38_liver',
#        '39_give', '40_root', '41_dog', '42_bone', '43_stick', '44_child',
#        '45_sea', '46_good', '47_drink', '48_and', '49_river', '50_river',
#        '51_black', '52_red', '53_thick', '54_breathe', '55_lake',
#        '56_flower', '57_bad', '58_yellow', '59_ash', '60_livealive',
#        '61_fire', '62_egg', '63_sharp', '64_horn', '65_foot', '66_freeze',
#        '67_near', '68_cut', '69_see', '70_wide', '71_tie', '72_pull',
#        '73_come', '74_old', '75_cold', '76_flow', '77_path', '78_green',
#        '79_full', '80_name', '81_mather', '82_holdtake', '83_where',
#        '84_that', '85_there', '86_man', '87_you', '88_year', '89_bird',
#        '90_woman'], dtype=object)

# %%
len(words)
# Out:
# 203

# %% [markdown]
# step 2 under the same word, test the value/form/segements difference among different areas

# %% [markdown]
# But with what method to calculate the phonetics difference? Use value /Form or Segments

# %% [markdown]
# step3 Raise some questions related with the dialetcs' geography and explore it
